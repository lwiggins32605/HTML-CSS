# %% [markdown]
# ## Analysis

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import requests
import time
import urllib

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 606

# %% [markdown]
# ## Perform API Calls

# %%
# OpenWeatherMap API Key
api_key = "fc25346c3bba7b36dc752128ffe4ef81"

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + urllib.request.pathname2url(city)

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    print(city_url)

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=souillac
# Processing Record 2 of Set 1 | wuhu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=wuhu
# Processing Record 3 of Set 1 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=labuhan
# Processing Record 4 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=vaini
# Processing Record 5 of Set 1 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=kaitangata
# Processing Record 6 of Set 1 | ulaangom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=ulaangom
# Processing Record 7 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=mataura
# Processing Record 8 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=cape%20town
# Processing Record 9 of Set 1 | halalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=halalo
# City not found. Skipping...
# Processing Record 10 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=rikitea
# Processing Record 11 of Set 1 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=victoria
# Processing Record 12 of Set 1 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=mar%20del%20plata
# Processing Record 13 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=punta%20arenas
# Processing Record 14 of Set 1 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=pangnirtung
# Processing Record 15 of Set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=saskylakh
# Processing Record 16 of Set 1 | ewa beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=ewa%20beach
# Processing Record 17 of Set 1 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=comodoro%20rivadavia
# Processing Record 18 of Set 1 | skalistyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=skalistyy
# City not found. Skipping...
# Processing Record 19 of Set 1 | aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=aykhal
# Processing Record 20 of Set 1 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=new%20norfolk
# Processing Record 21 of Set 1 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=sitka
# Processing Record 22 of Set 1 | camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=camacha
# Processing Record 23 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=ushuaia
# Processing Record 24 of Set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=khatanga
# Processing Record 25 of Set 1 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=kahului
# Processing Record 26 of Set 1 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=alofi
# Processing Record 27 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=busselton
# Processing Record 28 of Set 1 | paka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=paka
# Processing Record 29 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=jamestown
# Processing Record 30 of Set 1 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=cockburn%20town
# Processing Record 31 of Set 1 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=bengkulu
# City not found. Skipping...
# Processing Record 32 of Set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=hithadhoo
# Processing Record 33 of Set 1 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=coihaique
# Processing Record 34 of Set 1 | inuvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=inuvik
# Processing Record 35 of Set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=castro
# Processing Record 36 of Set 1 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=vestmannaeyjar
# Processing Record 37 of Set 1 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=atuona
# Processing Record 39 of Set 1 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=kavieng
# Processing Record 40 of Set 1 | sirawai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=sirawai
# Processing Record 41 of Set 1 | hovd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=hovd
# Processing Record 42 of Set 1 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=faanui
# Processing Record 43 of Set 1 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=mount%20isa
# Processing Record 44 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=bredasdorp
# Processing Record 45 of Set 1 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=cherskiy
# Processing Record 46 of Set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=qaanaaq
# Processing Record 47 of Set 1 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=iqaluit
# Processing Record 48 of Set 1 | meadow lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=meadow%20lake
# Processing Record 49 of Set 1 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=norman%20wells
# Processing Record 50 of Set 1 | kirkwall
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=kirkwall
# Processing Record 0 of Set 2 | klyuchi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=klyuchi
# Processing Record 1 of Set 2 | warqla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=warqla
# City not found. Skipping...
# Processing Record 2 of Set 2 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=port-gentil
# Processing Record 3 of Set 2 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=hermanus
# Processing Record 4 of Set 2 | georgiyevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=georgiyevka
# Processing Record 5 of Set 2 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=chuy
# Processing Record 6 of Set 2 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 2 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=arraial%20do%20cabo
# Processing Record 8 of Set 2 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=adrar
# Processing Record 9 of Set 2 | sinjah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=sinjah
# City not found. Skipping...
# Processing Record 10 of Set 2 | knysna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=knysna
# Processing Record 11 of Set 2 | madang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=madang
# Processing Record 12 of Set 2 | marabba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=marabba
# Processing Record 13 of Set 2 | palimbang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=palimbang
# Processing Record 14 of Set 2 | zhovtneve
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=zhovtneve
# City not found. Skipping...
# Processing Record 15 of Set 2 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=saint-philippe
# Processing Record 16 of Set 2 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=yar-sale
# Processing Record 17 of Set 2 | issoire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=issoire
# Processing Record 18 of Set 2 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=carnarvon
# Processing Record 19 of Set 2 | gornopravdinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=gornopravdinsk
# Processing Record 20 of Set 2 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=salalah
# Processing Record 21 of Set 2 | moiyabana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=moiyabana
# City not found. Skipping...
# Processing Record 22 of Set 2 | salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=salinopolis
# Processing Record 23 of Set 2 | bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=bubaque
# Processing Record 24 of Set 2 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=puerto%20ayora
# Processing Record 25 of Set 2 | altamont
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=altamont
# Processing Record 26 of Set 2 | vence
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=vence
# Processing Record 27 of Set 2 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 2 | roald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=roald
# Processing Record 29 of Set 2 | padrauna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=padrauna
# Processing Record 30 of Set 2 | valparaiso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=valparaiso
# Processing Record 31 of Set 2 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=butaritari
# Processing Record 32 of Set 2 | cizre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=cizre
# Processing Record 33 of Set 2 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=albany
# Processing Record 34 of Set 2 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=leningradskiy
# Processing Record 35 of Set 2 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=dikson
# Processing Record 36 of Set 2 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=yellowknife
# Processing Record 37 of Set 2 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=hobart
# Processing Record 38 of Set 2 | aden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=aden
# Processing Record 39 of Set 2 | gujar khan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=gujar%20khan
# Processing Record 40 of Set 2 | jos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=jos
# Processing Record 41 of Set 2 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 2 | urumqi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=urumqi
# City not found. Skipping...
# Processing Record 43 of Set 2 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=torbay
# Processing Record 44 of Set 2 | riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=riyadh
# Processing Record 45 of Set 2 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=vila%20franca%20do%20campo
# Processing Record 46 of Set 2 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 2 | mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=mehamn
# Processing Record 48 of Set 2 | letterkenny
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=letterkenny
# Processing Record 49 of Set 2 | kushima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=kushima
# Processing Record 0 of Set 3 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 3 | along
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=along
# Processing Record 2 of Set 3 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=cabo%20san%20lucas
# Processing Record 3 of Set 3 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=ribeira%20grande
# Processing Record 4 of Set 3 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=upernavik
# Processing Record 5 of Set 3 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=klaksvik
# Processing Record 6 of Set 3 | purranque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=purranque
# Processing Record 7 of Set 3 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=husavik
# Processing Record 8 of Set 3 | harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=harper
# Processing Record 9 of Set 3 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=necochea
# Processing Record 10 of Set 3 | camana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=camana
# City not found. Skipping...
# Processing Record 11 of Set 3 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=avarua
# Processing Record 12 of Set 3 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=barrow
# Processing Record 13 of Set 3 | xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=xining
# Processing Record 14 of Set 3 | dryden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=dryden
# Processing Record 15 of Set 3 | hammerfest
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=hammerfest
# Processing Record 16 of Set 3 | samusu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=samusu
# City not found. Skipping...
# Processing Record 17 of Set 3 | sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=sola
# Processing Record 18 of Set 3 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=quatre%20cocos
# Processing Record 19 of Set 3 | sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=sisimiut
# Processing Record 20 of Set 3 | sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=sur
# Processing Record 21 of Set 3 | saint andrews
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=saint%20andrews
# Processing Record 22 of Set 3 | yerofey pavlovich
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=yerofey%20pavlovich
# Processing Record 23 of Set 3 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=georgetown
# Processing Record 24 of Set 3 | isla vista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=isla%20vista
# Processing Record 25 of Set 3 | carballo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=carballo
# Processing Record 26 of Set 3 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=codrington
# Processing Record 27 of Set 3 | akkermanovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=akkermanovka
# City not found. Skipping...
# Processing Record 28 of Set 3 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=port%20elizabeth
# Processing Record 29 of Set 3 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=tiksi
# Processing Record 30 of Set 3 | tidore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=tidore
# City not found. Skipping...
# Processing Record 31 of Set 3 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=mys%20shmidta
# City not found. Skipping...
# Processing Record 32 of Set 3 | aksu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=aksu
# Processing Record 33 of Set 3 | sibu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=sibu
# Processing Record 34 of Set 3 | elliot lake
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=elliot%20lake
# Processing Record 35 of Set 3 | darovskoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=darovskoy
# Processing Record 36 of Set 3 | roma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=roma
# Processing Record 37 of Set 3 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=provideniya
# Processing Record 38 of Set 3 | lingao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=lingao
# Processing Record 39 of Set 3 | fayaoue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=fayaoue
# Processing Record 40 of Set 3 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=constitucion
# Processing Record 41 of Set 3 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=beringovskiy
# Processing Record 42 of Set 3 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=cidreira
# Processing Record 43 of Set 3 | petropavlovskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=petropavlovskoye
# Processing Record 44 of Set 3 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=narsaq
# Processing Record 45 of Set 3 | gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=gat
# Processing Record 46 of Set 3 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=sorland
# Processing Record 47 of Set 3 | guiratinga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=guiratinga
# Processing Record 48 of Set 3 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=aklavik
# Processing Record 49 of Set 3 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=nikolskoye
# Processing Record 0 of Set 4 | shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=shingu
# Processing Record 1 of Set 4 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=vila%20velha
# Processing Record 2 of Set 4 | pacifica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=pacifica
# Processing Record 3 of Set 4 | puerto carreno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=puerto%20carreno
# Processing Record 4 of Set 4 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=saint%20george
# Processing Record 5 of Set 4 | umm kaddadah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=umm%20kaddadah
# Processing Record 6 of Set 4 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=tuktoyaktuk
# Processing Record 7 of Set 4 | marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=marcona
# City not found. Skipping...
# Processing Record 8 of Set 4 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=cayenne
# Processing Record 9 of Set 4 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=bluff
# Processing Record 10 of Set 4 | awjilah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=awjilah
# Processing Record 11 of Set 4 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=port%20alfred
# Processing Record 12 of Set 4 | kachiry
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=kachiry
# Processing Record 13 of Set 4 | chifeng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=chifeng
# Processing Record 14 of Set 4 | conceicao do araguaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=conceicao%20do%20araguaia
# Processing Record 15 of Set 4 | calabar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=calabar
# Processing Record 16 of Set 4 | pappadatai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=pappadatai
# Processing Record 17 of Set 4 | chagda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=chagda
# City not found. Skipping...
# Processing Record 18 of Set 4 | boden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=boden
# Processing Record 19 of Set 4 | shamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=shamary
# Processing Record 20 of Set 4 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=grand%20river%20south%20east
# City not found. Skipping...
# Processing Record 21 of Set 4 | mnogovershinnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=mnogovershinnyy
# Processing Record 22 of Set 4 | shintomi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=shintomi
# Processing Record 23 of Set 4 | baruun-urt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=baruun-urt
# Processing Record 24 of Set 4 | sept-iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=sept-iles
# Processing Record 25 of Set 4 | acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=acapulco
# Processing Record 26 of Set 4 | mishelevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=mishelevka
# Processing Record 27 of Set 4 | duekoue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=duekoue
# Processing Record 28 of Set 4 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=naze
# Processing Record 29 of Set 4 | lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=lasa
# Processing Record 30 of Set 4 | richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=richards%20bay
# Processing Record 31 of Set 4 | banda aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=banda%20aceh
# Processing Record 32 of Set 4 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=airai
# Processing Record 33 of Set 4 | saint-leu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=saint-leu
# Processing Record 34 of Set 4 | satitoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=satitoa
# City not found. Skipping...
# Processing Record 35 of Set 4 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=chokurdakh
# Processing Record 36 of Set 4 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=kapaa
# Processing Record 37 of Set 4 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=taoudenni
# Processing Record 38 of Set 4 | korhogo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=korhogo
# Processing Record 39 of Set 4 | moyale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=moyale
# Processing Record 40 of Set 4 | salair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=salair
# Processing Record 41 of Set 4 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=qaqortoq
# Processing Record 42 of Set 4 | belyy yar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=belyy%20yar
# Processing Record 43 of Set 4 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=sao%20joao%20da%20barra
# Processing Record 44 of Set 4 | abramovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=abramovka
# Processing Record 45 of Set 4 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=port%20macquarie
# Processing Record 46 of Set 4 | ndioum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=ndioum
# Processing Record 47 of Set 4 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=bambous%20virieux
# Processing Record 48 of Set 4 | guiglo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=guiglo
# Processing Record 49 of Set 4 | hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=hirara
# Processing Record 0 of Set 5 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=amderma
# City not found. Skipping...
# Processing Record 1 of Set 5 | nong phai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=nong%20phai
# Processing Record 2 of Set 5 | scottsburgh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=scottsburgh
# City not found. Skipping...
# Processing Record 3 of Set 5 | cowansville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=cowansville
# Processing Record 4 of Set 5 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=mahebourg
# Processing Record 5 of Set 5 | balykshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=balykshi
# City not found. Skipping...
# Processing Record 6 of Set 5 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=kodiak
# Processing Record 7 of Set 5 | gambela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=gambela
# Processing Record 8 of Set 5 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=lorengau
# Processing Record 9 of Set 5 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=oranjemund
# Processing Record 10 of Set 5 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=sao%20filipe
# Processing Record 11 of Set 5 | rawannawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=rawannawi
# City not found. Skipping...
# Processing Record 12 of Set 5 | goure
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=goure
# Processing Record 13 of Set 5 | ludvika
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=ludvika
# Processing Record 14 of Set 5 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=grindavik
# Processing Record 15 of Set 5 | antsohihy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=antsohihy
# Processing Record 16 of Set 5 | louisbourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 5 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 5 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=katsuura
# Processing Record 19 of Set 5 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=luderitz
# Processing Record 20 of Set 5 | porto nacional
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=porto%20nacional
# Processing Record 21 of Set 5 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=port%20blair
# Processing Record 22 of Set 5 | bouar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=bouar
# Processing Record 23 of Set 5 | askino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=askino
# Processing Record 24 of Set 5 | sri aman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=sri%20aman
# Processing Record 25 of Set 5 | tottori
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=tottori
# Processing Record 26 of Set 5 | cheuskiny
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=cheuskiny
# City not found. Skipping...
# Processing Record 27 of Set 5 | bababe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=bababe
# City not found. Skipping...
# Processing Record 28 of Set 5 | katha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=katha
# City not found. Skipping...
# Processing Record 29 of Set 5 | riorges
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=riorges
# Processing Record 30 of Set 5 | takhtamygda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=takhtamygda
# Processing Record 31 of Set 5 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=belushya%20guba
# City not found. Skipping...
# Processing Record 32 of Set 5 | oskarshamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=oskarshamn
# Processing Record 33 of Set 5 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=severo-kurilsk
# Processing Record 34 of Set 5 | alim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=alim
# Processing Record 35 of Set 5 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=east%20london
# Processing Record 36 of Set 5 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=bathsheba
# Processing Record 37 of Set 5 | itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=itarema
# Processing Record 38 of Set 5 | butembo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=butembo
# Processing Record 39 of Set 5 | portoferraio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=portoferraio
# Processing Record 40 of Set 5 | akcakoca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=akcakoca
# Processing Record 41 of Set 5 | licheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=licheng
# Processing Record 42 of Set 5 | balkhash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=balkhash
# Processing Record 43 of Set 5 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=ilulissat
# Processing Record 44 of Set 5 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=ambilobe
# Processing Record 45 of Set 5 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=saldanha
# Processing Record 46 of Set 5 | zhangjiakou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=zhangjiakou
# Processing Record 47 of Set 5 | vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=vao
# Processing Record 48 of Set 5 | sistranda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=sistranda
# Processing Record 49 of Set 5 | angoram
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=angoram
# Processing Record 0 of Set 6 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=flinders
# Processing Record 1 of Set 6 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=nanortalik
# Processing Record 2 of Set 6 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=port%20hardy
# Processing Record 3 of Set 6 | flin flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=flin%20flon
# Processing Record 4 of Set 6 | general roca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=general%20roca
# Processing Record 5 of Set 6 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=lebu
# Processing Record 6 of Set 6 | laurel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=laurel
# Processing Record 7 of Set 6 | nyandoma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=nyandoma
# Processing Record 8 of Set 6 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=sobolevo
# Processing Record 9 of Set 6 | paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=paamiut
# Processing Record 10 of Set 6 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=ponta%20delgada
# Processing Record 11 of Set 6 | vizinga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=vizinga
# Processing Record 12 of Set 6 | neiafu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=neiafu
# Processing Record 13 of Set 6 | ewing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=ewing
# Processing Record 14 of Set 6 | tulun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=tulun
# Processing Record 15 of Set 6 | huilong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=huilong
# Processing Record 16 of Set 6 | mezen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=mezen
# Processing Record 17 of Set 6 | khandyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=khandyga
# Processing Record 18 of Set 6 | mangrol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=mangrol
# Processing Record 19 of Set 6 | mabaruma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=mabaruma
# Processing Record 20 of Set 6 | saleaula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=saleaula
# City not found. Skipping...
# Processing Record 21 of Set 6 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=ancud
# Processing Record 22 of Set 6 | umm ruwabah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=umm%20ruwabah
# City not found. Skipping...
# Processing Record 23 of Set 6 | jumla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=jumla
# Processing Record 24 of Set 6 | umm lajj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=umm%20lajj
# Processing Record 25 of Set 6 | amapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=amapa
# Processing Record 26 of Set 6 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=port%20lincoln
# Processing Record 27 of Set 6 | kathu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=kathu
# Processing Record 28 of Set 6 | honningsvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=honningsvag
# Processing Record 29 of Set 6 | chapleau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=chapleau
# Processing Record 30 of Set 6 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=pisco
# Processing Record 31 of Set 6 | adolfo lopez mateos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=adolfo%20lopez%20mateos
# Processing Record 32 of Set 6 | moranbah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=moranbah
# Processing Record 33 of Set 6 | west wendover
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=west%20wendover
# Processing Record 34 of Set 6 | sibolga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=sibolga
# Processing Record 35 of Set 6 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=petropavlovsk-kamchatskiy
# Processing Record 36 of Set 6 | tromso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=tromso
# Processing Record 37 of Set 6 | bagdarin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=bagdarin
# Processing Record 38 of Set 6 | ivybridge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=ivybridge
# Processing Record 39 of Set 6 | olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=olinda
# Processing Record 40 of Set 6 | buqayq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=buqayq
# City not found. Skipping...
# Processing Record 41 of Set 6 | la huacana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=la%20huacana
# Processing Record 42 of Set 6 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=egvekinot
# Processing Record 43 of Set 6 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=clyde%20river
# Processing Record 44 of Set 6 | katherine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=katherine
# Processing Record 45 of Set 6 | mauswagon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=mauswagon
# City not found. Skipping...
# Processing Record 46 of Set 6 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=portland
# Processing Record 47 of Set 6 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=tasiilaq
# Processing Record 48 of Set 6 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=pacific%20grove
# Processing Record 49 of Set 6 | araouane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=araouane
# Processing Record 0 of Set 7 | tashir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=tashir
# Processing Record 1 of Set 7 | joigny
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=joigny
# Processing Record 2 of Set 7 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=kruisfontein
# Processing Record 3 of Set 7 | guerrero negro
# ...
# Processing Record 6 of Set 11 | vigeland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=vigeland
# Processing Record 7 of Set 11 | anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=anadyr
# Processing Record 8 of Set 11 | jinka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=jinka
# Processing Record 9 of Set 11 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=geraldton
# Processing Record 10 of Set 11 | trastenik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=trastenik
# Processing Record 11 of Set 11 | tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=tautira
# Processing Record 12 of Set 11 | takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=takoradi
# Processing Record 13 of Set 11 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=deputatskiy
# Processing Record 14 of Set 11 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=fort%20nelson
# Processing Record 15 of Set 11 | mut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=mut
# Processing Record 16 of Set 11 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=vardo
# Processing Record 17 of Set 11 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=talnakh
# Processing Record 18 of Set 11 | rafsanjan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=rafsanjan
# Processing Record 19 of Set 11 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=grand%20gaube
# Processing Record 20 of Set 11 | erzin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=erzin
# Processing Record 21 of Set 11 | tamandare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=tamandare
# Processing Record 22 of Set 11 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=berlevag
# Processing Record 23 of Set 11 | siavonga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=siavonga
# Processing Record 24 of Set 11 | kenai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=kenai
# Processing Record 25 of Set 11 | cheyenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=cheyenne
# Processing Record 26 of Set 11 | varhaug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=varhaug
# Processing Record 27 of Set 11 | ziyamet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=ziyamet
# City not found. Skipping...
# Processing Record 28 of Set 11 | khonuu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=khonuu
# City not found. Skipping...
# Processing Record 29 of Set 11 | siswa bazar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=siswa%20bazar
# Processing Record 30 of Set 11 | arman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=arman
# Processing Record 31 of Set 11 | ondorhaan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=ondorhaan
# City not found. Skipping...
# Processing Record 32 of Set 11 | palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=palmer
# Processing Record 33 of Set 11 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=lata
# Processing Record 34 of Set 11 | rungata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=rungata
# City not found. Skipping...
# Processing Record 35 of Set 11 | basco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=basco
# Processing Record 36 of Set 11 | abu dhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=abu%20dhabi
# Processing Record 37 of Set 11 | cairns
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=cairns
# Processing Record 38 of Set 11 | cagayan de tawi-tawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=cagayan%20de%20tawi-tawi
# City not found. Skipping...
# Processing Record 39 of Set 11 | lumby
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=lumby
# Processing Record 40 of Set 11 | bajina basta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=bajina%20basta
# Processing Record 41 of Set 11 | taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=taltal
# Processing Record 42 of Set 11 | syracuse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=syracuse
# Processing Record 43 of Set 11 | viligili
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=viligili
# City not found. Skipping...
# Processing Record 44 of Set 11 | atalaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=atalaia
# Processing Record 45 of Set 11 | kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=kalmunai
# Processing Record 46 of Set 11 | morant bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=morant%20bay
# Processing Record 47 of Set 11 | sedelnikovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=sedelnikovo
# City not found. Skipping...
# Processing Record 48 of Set 11 | xinzhi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=xinzhi
# Processing Record 49 of Set 11 | shatki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=shatki
# Processing Record 0 of Set 12 | san policarpo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=san%20policarpo
# Processing Record 1 of Set 12 | shahganj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=shahganj
# Processing Record 2 of Set 12 | ust-karsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=ust-karsk
# Processing Record 3 of Set 12 | minbu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=minbu
# Processing Record 4 of Set 12 | byron bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=byron%20bay
# Processing Record 5 of Set 12 | kurchum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=kurchum
# Processing Record 6 of Set 12 | ilam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=ilam
# Processing Record 7 of Set 12 | myingyan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=myingyan
# Processing Record 8 of Set 12 | alyangula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=alyangula
# Processing Record 9 of Set 12 | kintampo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=kintampo
# Processing Record 10 of Set 12 | broken hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=broken%20hill
# Processing Record 11 of Set 12 | kholm
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=kholm
# Processing Record 12 of Set 12 | chlorakas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=chlorakas
# City not found. Skipping...
# Processing Record 13 of Set 12 | tevaitoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=tevaitoa
# Processing Record 14 of Set 12 | am timan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=am%20timan
# Processing Record 15 of Set 12 | hukuntsi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=hukuntsi
# Processing Record 16 of Set 12 | pitimbu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=pitimbu
# Processing Record 17 of Set 12 | mugur-aksy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=mugur-aksy
# Processing Record 18 of Set 12 | carmen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=carmen
# Processing Record 19 of Set 12 | kupang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=kupang
# Processing Record 20 of Set 12 | abu kamal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=abu%20kamal
# Processing Record 21 of Set 12 | san-pedro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=san-pedro
# Processing Record 22 of Set 12 | cartagena del chaira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=cartagena%20del%20chaira
# Processing Record 23 of Set 12 | lukulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=lukulu
# Processing Record 24 of Set 12 | haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=haines%20junction
# Processing Record 25 of Set 12 | imperial
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=imperial
# Processing Record 26 of Set 12 | atambua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=atambua
# Processing Record 27 of Set 12 | zhuhai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=zhuhai
# Processing Record 28 of Set 12 | toamasina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=toamasina
# Processing Record 29 of Set 12 | murchison
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=murchison
# Processing Record 30 of Set 12 | saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=saint-francois
# Processing Record 31 of Set 12 | fort saint john
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=fort%20saint%20john
# City not found. Skipping...
# Processing Record 32 of Set 12 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=alta%20floresta
# Processing Record 33 of Set 12 | ponnani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=ponnani
# Processing Record 34 of Set 12 | avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=avera
# Processing Record 35 of Set 12 | sturgeon falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=sturgeon%20falls
# Processing Record 36 of Set 12 | tavira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=tavira
# Processing Record 37 of Set 12 | hazaribag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=hazaribag
# Processing Record 38 of Set 12 | tumannyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 12 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=ixtapa
# Processing Record 40 of Set 12 | shitkino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=shitkino
# Processing Record 41 of Set 12 | leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=leshukonskoye
# Processing Record 42 of Set 12 | damietta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=damietta
# Processing Record 43 of Set 12 | kamenskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 12 | naantali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=naantali
# Processing Record 45 of Set 12 | road town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=road%20town
# Processing Record 46 of Set 12 | altagracia de orituco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=altagracia%20de%20orituco
# Processing Record 47 of Set 12 | gogapur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=gogapur
# Processing Record 48 of Set 12 | berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=berdigestyakh
# Processing Record 49 of Set 12 | callaway
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=callaway
# Processing Record 0 of Set 13 | buzmeyin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=buzmeyin
# Processing Record 1 of Set 13 | nanlong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=nanlong
# Processing Record 2 of Set 13 | grand centre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=grand%20centre
# City not found. Skipping...
# Processing Record 3 of Set 13 | otjimbingwe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=otjimbingwe
# Processing Record 4 of Set 13 | shelton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=shelton
# Processing Record 5 of Set 13 | tommot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fc25346c3bba7b36dc752128ffe4ef81&q=tommot
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Extract relevant fields from the data frame
lats = city_data_pd["Lat"]
max_temps = city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]

# Export the City_Data into a csv
city_data_pd.to_csv(output_data_file, index_label="City_ID")

# Show Record Count
city_data_pd.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6c8fc7b93d75> in <module>
#       1 # Convert array of JSONs into Pandas DataFrame
# ----> 2 city_data_pd = pd.DataFrame(city_data)
#       3
#       4 # Extract relevant fields from the data frame
#       5 lats = city_data_pd["Lat"]
#
# NameError: name 'city_data' is not defined

# %%
# Display the City Data Frame
city_data_pd.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-b4fee7a83e79> in <module>
#       1 # Display the City Data Frame
# ----> 2 city_data_pd.head()
#
# NameError: name 'city_data_pd' is not defined

# %% [markdown]
# ## Latitude vs Temperature Plot

# %%
# Build scatter plot for latitude vs temperature
plt.scatter(lats, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build the scatter plots for each city types
plt.scatter(lats, 
            humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for each city types
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for each city types
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()
